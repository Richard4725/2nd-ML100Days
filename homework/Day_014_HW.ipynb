# %% [markdown]
# ## 作業
# ### 請使用 application_train.csv, 根據不同的 HOUSETYPE_MODE 對 AMT_CREDIT 繪製 Histogram

# %% [markdown]
# # [作業目標]
# - 試著調整資料, 並利用提供的程式繪製分布圖

# %% [markdown]
# # [作業重點]
# - 如何將列出相異的 HOUSETYPE_MODE 類別 (In[3])
# - 如何依照不同的 HOUSETYPE_MODE 類別指定資料, 並繪製長條圖(.hist())? (In[3])

# %%
# 載入需要的套件
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns # 另一個繪圖-樣式套件

# 忽略警告訊息
# %matplotlib inline
plt.style.use('ggplot')
import warnings
warnings.filterwarnings('ignore')

# 設定 data_path
dir_data = 'D:\\100days\data'

# %%
# 讀取檔案
f_app = os.path.join(dir_data, 'application_train.csv')
print('Path of read in data: %s' % (f_app))
app_train = pd.read_csv(f_app)
app_train.head()

print(app_train['HOUSETYPE_MODE'])
print(app_train['AMT_CREDIT'])
# Out:
# Path of read in data: D:\100days\data\application_train.csv
# 0         block of flats
# 1         block of flats
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12        block of flats
# 13        block of flats
# 14        block of flats
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18        block of flats
# 19                   NaN
# 20        block of flats
# 21                   NaN
# 22        block of flats
# 23        block of flats
# 24        block of flats
# 25        block of flats
# 26        block of flats
# 27                   NaN
# 28                   NaN
# 29        block of flats
#                ...
# 307481               NaN
# 307482    block of flats
# 307483    block of flats
# 307484               NaN
# 307485               NaN
# 307486    block of flats
# 307487               NaN
# 307488               NaN
# 307489    block of flats
# 307490               NaN
# 307491               NaN
# 307492               NaN
# 307493               NaN
# 307494               NaN
# 307495    block of flats
# 307496               NaN
# 307497               NaN
# 307498    block of flats
# 307499               NaN
# 307500    block of flats
# 307501    block of flats
# 307502               NaN
# 307503               NaN
# 307504               NaN
# 307505    block of flats
# 307506    block of flats
# 307507    block of flats
# 307508    block of flats
# 307509    block of flats
# 307510    block of flats
# Name: HOUSETYPE_MODE, Length: 307511, dtype: object
# 0          406597.5
# 1         1293502.5
# 2          135000.0
# 3          312682.5
# 4          513000.0
# 5          490495.5
# 6         1560726.0
# 7         1530000.0
# 8         1019610.0
# 9          405000.0
# 10         652500.0
# 11         148365.0
# 12          80865.0
# 13         918468.0
# 14         773680.5
# 15         299772.0
# 16         509602.5
# 17         270000.0
# 18         157500.0
# 19         544491.0
# 20         427500.0
# 21        1132573.5
# 22         497520.0
# 23         239850.0
# 24         247500.0
# 25         225000.0
# 26         979992.0
# 27         327024.0
# 28         790830.0
# 29         180000.0
#             ...
# 307481     297000.0
# 307482     500566.5
# 307483     247275.0
# 307484     545040.0
# 307485     180000.0
# 307486     355536.0
# 307487    1071909.0
# 307488     135000.0
# 307489     521280.0
# 307490     135000.0
# 307491    1078200.0
# 307492    1575000.0
# 307493     946764.0
# 307494     479700.0
# 307495     808650.0
# 307496     337500.0
# 307497     270126.0
# 307498    1312110.0
# 307499     225000.0
# 307500    1303812.0
# 307501     269550.0
# 307502     225000.0
# 307503     345510.0
# 307504     331920.0
# 307505     225000.0
# 307506     254700.0
# 307507     269550.0
# 307508     677664.0
# 307509     370107.0
# 307510     675000.0
# Name: AMT_CREDIT, Length: 307511, dtype: float64

# %%
# 使用不同的 HOUSETYPE_MODE 類別繪製圖形, 並使用 subplot 排版
"""
Your Code Here
"""
unique_house_type =app_train['HOUSETYPE_MODE'].unique()
print(unique_house_type)
nrows = len(unique_house_type)
ncols = nrows // 2

plt.figure(figsize=(10,30))
for i in range(len(unique_house_type)):
    plt.subplot(nrows, ncols, i+1)
    """
    Your Code Here
    """
    
    app_train.loc[app_train["HOUSETYPE_MODE"]==unique_house_type[i],"HOUSETYPE_MODE"].hist()
    print(app_train.loc[app_train["HOUSETYPE_MODE"]==unique_house_type[i],"HOUSETYPE_MODE"])
    plt.title(str(unique_house_type[i]))
plt.show()
# Out:
# ['block of flats' nan 'terraced house' 'specific housing']
# 0         block of flats
# 1         block of flats
# 12        block of flats
# 13        block of flats
# 14        block of flats
# 18        block of flats
# 20        block of flats
# 22        block of flats
# 23        block of flats
# 24        block of flats
# 25        block of flats
# 26        block of flats
# 29        block of flats
# 30        block of flats
# 31        block of flats
# 32        block of flats
# 34        block of flats
# 35        block of flats
# 38        block of flats
# 39        block of flats
# 40        block of flats
# 43        block of flats
# 50        block of flats
# 51        block of flats
# 52        block of flats
# 54        block of flats
# 55        block of flats
# 57        block of flats
# 59        block of flats
# 60        block of flats
#                ...
# 307459    block of flats
# 307461    block of flats
# 307462    block of flats
# 307463    block of flats
# 307464    block of flats
# 307465    block of flats
# 307466    block of flats
# 307467    block of flats
# 307468    block of flats
# 307469    block of flats
# 307474    block of flats
# 307475    block of flats
# 307476    block of flats
# 307477    block of flats
# 307478    block of flats
# 307480    block of flats
# 307482    block of flats
# 307483    block of flats
# 307486    block of flats
# 307489    block of flats
# 307495    block of flats
# 307498    block of flats
# 307500    block of flats
# 307501    block of flats
# 307505    block of flats
# 307506    block of flats
# 307507    block of flats
# 307508    block of flats
# 307509    block of flats
# 307510    block of flats
# Name: HOUSETYPE_MODE, Length: 150503, dtype: object
# Series([], Name: HOUSETYPE_MODE, dtype: object)
# 207       terraced house
# 606       terraced house
# 995       terraced house
# 1155      terraced house
# 1163      terraced house
# 1270      terraced house
# 1896      terraced house
# 2045      terraced house
# 2049      terraced house
# 2058      terraced house
# 2065      terraced house
# 2621      terraced house
# 2977      terraced house
# 3233      terraced house
# 3348      terraced house
# 3662      terraced house
# 3862      terraced house
# 3976      terraced house
# 4180      terraced house
# 4225      terraced house
# 4389      terraced house
# 4974      terraced house
# 5574      terraced house
# 6034      terraced house
# 6069      terraced house
# 6526      terraced house
# 7250      terraced house
# 7313      terraced house
# 7327      terraced house
# 7346      terraced house
#                ...
# 301013    terraced house
# 302381    terraced house
# 302503    terraced house
# 302696    terraced house
# 303367    terraced house
# 303467    terraced house
# 303612    terraced house
# 303637    terraced house
# 303769    terraced house
# 303929    terraced house
# 303992    terraced house
# 304072    terraced house
# 304447    terraced house
# 304594    terraced house
# 304657    terraced house
# 304672    terraced house
# 304766    terraced house
# 304886    terraced house
# 305078    terraced house
# 305147    terraced house
# 305631    terraced house
# 305705    terraced house
# 305776    terraced house
# 306411    terraced house
# 306675    terraced house
# 306788    terraced house
# 307060    terraced house
# 307166    terraced house
# 307315    terraced house
# 307457    terraced house
# Name: HOUSETYPE_MODE, Length: 1212, dtype: object
# 349       specific housing
# 435       specific housing
# 453       specific housing
# 814       specific housing
# 1425      specific housing
# 1440      specific housing
# 2021      specific housing
# 2094      specific housing
# 2216      specific housing
# 2404      specific housing
# 2501      specific housing
# 2947      specific housing
# 3159      specific housing
# 3565      specific housing
# 3663      specific housing
# 3917      specific housing
# 3923      specific housing
# 4269      specific housing
# 4372      specific housing
# 4437      specific housing
# 4448      specific housing
# 5126      specific housing
# 6176      specific housing
# 6337      specific housing
# 6357      specific housing
# 6433      specific housing
# 6447      specific housing
# 6656      specific housing
# 7146      specific housing
# 7445      specific housing
#                 ...
# 301867    specific housing
# 302074    specific housing
# 302380    specific housing
# 302525    specific housing
# 302588    specific housing
# 303208    specific housing
# 303332    specific housing
# 303397    specific housing
# 303441    specific housing
# 303504    specific housing
# 303575    specific housing
# 303813    specific housing
# 303836    specific housing
# 303988    specific housing
# 304357    specific housing
# 304379    specific housing
# 304467    specific housing
# 304835    specific housing
# 305213    specific housing
# 305453    specific housing
# 305592    specific housing
# 305667    specific housing
# 305892    specific housing
# 306328    specific housing
# 306517    specific housing
# 306639    specific housing
# 306917    specific housing
# 306934    specific housing
# 307141    specific housing
# 307242    specific housing
# Name: HOUSETYPE_MODE, Length: 1499, dtype: object
