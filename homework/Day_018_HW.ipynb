# %% [markdown]
# # 作業 : (Kaggle)鐵達尼生存預測

# %% [markdown]
# # [作業目標]
# - 試著完成三種不同特徵類型的三種資料操作, 觀察結果
# - 思考一下, 這三種特徵類型, 哪一種應該最複雜/最難處理

# %% [markdown]
# # [作業重點]
# - 完成剩餘的八種 類型 x 操作組合 (In[6]~In[13], Out[6]~Out[13])
# - 思考何種特徵類型, 應該最複雜

# %%
# 載入基本套件
import pandas as pd
import numpy as np

# 讀取訓練與測試資料
data_path = 'D:/100days/data/'
df_train = pd.read_csv(data_path + 'titanic_train.csv')
df_test = pd.read_csv(data_path + 'titanic_test.csv')
print(df_train.shape)
print(df_test.shape)
# Out:
# (891, 12)
# (418, 11)

# %%
# 重組資料成為訓練 / 預測用格式
train_Y = df_train['Survived']
print('train_Y:',train_Y)
ids = df_test['PassengerId']
print('ids:',ids)
df_train = df_train.drop(['PassengerId', 'Survived'] , axis=1)
print('df_train:',df_train)
df_test = df_test.drop(['PassengerId'] , axis=1)
print('df_test:',df_test)
df = pd.concat([df_train,df_test])
print('df:',df)

print(df.shape)
df.head()
# Out:
# train_Y: 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64
# ids: 0       892
# 1       893
# 2       894
# 3       895
# 4       896
# 5       897
# 6       898
# 7       899
# 8       900
# 9       901
# 10      902
# 11      903
# 12      904
# 13      905
# 14      906
# 15      907
# 16      908
# 17      909
# 18      910
# ...

# %%
# 秀出資料欄位的類型與數量
dtype_df = df.dtypes.reset_index()
print('dtype_df:',dtype_df)
dtype_df.columns = ["Count", "Column Type"]
print('dtype_df:',dtype_df)
dtype_df = dtype_df.groupby("Column Type").aggregate('count').reset_index()
print('dtype_df:',dtype_df)
dtype_df
# Out:
# dtype_df:       index        0
# 0    Pclass    int64
# 1      Name   object
# 2       Sex   object
# 3       Age  float64
# 4     SibSp    int64
# 5     Parch    int64
# 6    Ticket   object
# 7      Fare  float64
# 8     Cabin   object
# 9  Embarked   object
# dtype_df:       Count Column Type
# 0    Pclass       int64
# 1      Name      object
# 2       Sex      object
# 3       Age     float64
# 4     SibSp       int64
# 5     Parch       int64
# 6    Ticket      object
# 7      Fare     float64
# 8     Cabin      object
# 9  Embarked      object
# dtype_df:   Column Type  Count
# 0       int64      3
# 1     float64      2
# 2      object      5
#   Column Type  Count
# 0       int64      3
# 1     float64      2
# 2      object      5

# %%
#確定只有 int64, float64, object 三種類型後, 分別將欄位名稱存於三個 list 中
int_features = []
float_features = []
object_features = []
for dtype, feature in zip(df.dtypes, df.columns):
    if dtype == 'float64':
        float_features.append(feature)
    elif dtype == 'int64':
        int_features.append(feature)
    else:
        object_features.append(feature)
print(f'{len(int_features)} Integer Features : {int_features}\n')
print(f'{len(float_features)} Float Features : {float_features}\n')
print(f'{len(object_features)} Object Features : {object_features}')
# Out:
# 3 Integer Features : ['Pclass', 'SibSp', 'Parch']
#
# 2 Float Features : ['Age', 'Fare']
#
# 5 Object Features : ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %% [markdown]
# # 作業1
# * 試著執行作業程式，觀察三種類型 (int / float / object) 的欄位分別進行( 平均 mean / 最大值 Max / 相異值 nunique )
# 中的九次操作會有那些問題? 並試著解釋那些發生Error的程式區塊的原因?
# =>ANS:object最複雜,最難處理.因為1. mean值算出出來. 2.Name max也並非真的max值,原因object並數值(非 int ,float),若取mean 與max
#
# # 作業2
# * 思考一下，試著舉出今天五種類型以外的一種或多種資料類型，你舉出的新類型是否可以歸在三大類中的某些大類?
# 所以三大類特徵中，哪一大類處理起來應該最複雜?
# =>ANS:object最複雜,我們可以對其進行編碼,但如何若編碼表示其意義,其實不容易,還有用(Label Encoding),也容易對object造成誤解,因為數字差異大小可能不具有意義

# %%
# 例 : 整數 (int) 特徵取平均 (mean)
df[int_features].mean()
# Out:
# Pclass    2.294882
# SibSp     0.498854
# Parch     0.385027
# dtype: float64

# %%
# 請依序列出 三種特徵類型 (int / float / object) x 三種方法 (平均 mean / 最大值 Max / 相異值 nunique) 的其餘操作
"""
Your Code Here
"""
df[int_features].max()
# Out:
# Pclass    3
# SibSp     8
# Parch     9
# dtype: int64

# %%
df[int_features].nunique()
# Out:
# Pclass    3
# SibSp     7
# Parch     8
# dtype: int64

# %%
df[float_features].mean()
# Out:
# Age     29.881138
# Fare    33.295479
# dtype: float64

# %%
df[float_features].max()
# Out:
# Age      80.0000
# Fare    512.3292
# dtype: float64

# %%
df[float_features].nunique()
# Out:
# Age      98
# Fare    281
# dtype: int64

# %%
df[object_features].mean()
# Out:
# Series([], dtype: float64)

# %%
df[object_features].max()
# Out:
# Name      van Melkebeke, Mr. Philemon
# Sex                              male
# Ticket                      WE/P 5735
# dtype: object

# %%
df[object_features].nunique()
# Out:
# Name        1307
# Sex            2
# Ticket       929
# Cabin        186
# Embarked       3
# dtype: int64
