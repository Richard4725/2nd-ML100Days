# %%
作業1：

請上 Kaggle, 在 Compe

titions 或 Dataset 中找一組競賽或資料並寫下：

1. 你選的這組資料為何重要
ANS: Exoplanet Hunting in Deep Space
藉由資料分析,去尋找系外行星
https://www.kaggle.com/keplersmachines/kepler-labelled-time-series-data


2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
ANS:資料可以從Kepler 太空望遠鏡觀察恆星亮度變化,因為行星本身不發光,藉由衍星方式,可以推斷該恆星系統有行星環繞,之前有團隊利用AI方式,找到系外行星
    故資料收集由太空望遠鏡或是地面望遠鏡,觀測一段時間後,看他的光度變化來收集

3. 蒐集而來的資料型態為何
ANS: 型態為.csv檔,內容為星星光度隨時間變化的關係圖

4. 這組資料想解決的問題如何評估
ANS:應該可以根據現有料去train data,也許先用監督式機器學習,告知何者是系外行星,當機器認得pattern後,可以拿已知系外行星數據測試



作業2：

想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
ANS:提升業績 =>根據客戶屬性提供專業服務,如學生族群在上下課時間提供共乘優惠,上班族提供高級雙B接送,女性乘客提供女性司機,並根據每位旅客里程數與目的地,搭車時間,屬於群組做資料分析
你的假設=>車隊擁有20輛以上,司機有男有女,車輛有國產平價也有進口雙B,提供不同族群

2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
ANS:初期可以與大規模車隊收集資料,或是hire有經驗管理者或是與車隊購買大數據甚至開發APP,搭車軟體,建立客戶database與歸類客戶族群

3. 蒐集而來的資料型態為何
ANS:里程,起始點,搭車時間,年齡,性別,職業

4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
ANS:利用大數據歸納出,類別與種類並提供不同服務方式

# %%
import numpy as np
import matplotlib.pyplot as plt


w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101)     * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

y_hat = x_lin * w + b+10
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = sum((y - yp)**2) / len(y)
    return mse

MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 373.797
# The Mean absolute error is 15.545
