# %% [markdown]
# # 範例 : 計程車費率預測
# https://www.kaggle.com/c/new-york-city-taxi-fare-prediction

# %% [markdown]
# # [作業目標]
# - 使用並觀察特徵組合, 在計程車費率預測競賽的影響

# %% [markdown]
# # [作業重點]
# - 仿造範例並參考今日課程內容, 使用經緯度一圈的長度比的概念造出新特徵, 觀察有什麼影響 (In[6], Out[6])
# - 只使用上面所造的這個新特徵, 觀察有什麼影響 (In[7], Out[7])

# %%
# 做完特徵工程前的所有準備
import pandas as pd
import numpy as np
import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor

data_path = 'D:/100days/data/'
df = pd.read_csv(data_path + 'taxi_data1.csv')

train_Y = df['fare_amount']
df = df.drop(['fare_amount'] , axis=1)
df.head()
# Out:
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2011-10-21 23:54:10 UTC        -73.990580        40.761071
# 1  2015-02-03 10:42:03 UTC        -73.988403        40.723431
# 2  2014-03-16 18:58:58 UTC        -74.015785        40.715110
# 3  2009-06-13 16:10:54 UTC        -73.977322        40.787275
# 4  2014-06-12 03:25:56 UTC        -73.989683        40.729717
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.981128         40.758634                2
# 1         -73.989647         40.741695                1
# 2         -74.012029         40.707888                2
# 3         -73.958030         40.778838                3
# 4         -73.982490         40.761887                3

# %%
# 時間特徵分解方式:使用datetime
df['pickup_datetime'] = df['pickup_datetime'].apply(lambda x: datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S UTC'))
df['pickup_year'] = df['pickup_datetime'].apply(lambda x: datetime.datetime.strftime(x, '%Y')).astype('int64')
df['pickup_month'] = df['pickup_datetime'].apply(lambda x: datetime.datetime.strftime(x, '%m')).astype('int64')
df['pickup_day'] = df['pickup_datetime'].apply(lambda x: datetime.datetime.strftime(x, '%d')).astype('int64')
df['pickup_hour'] = df['pickup_datetime'].apply(lambda x: datetime.datetime.strftime(x, '%H')).astype('int64')
df['pickup_minute'] = df['pickup_datetime'].apply(lambda x: datetime.datetime.strftime(x, '%M')).astype('int64')
df['pickup_second'] = df['pickup_datetime'].apply(lambda x: datetime.datetime.strftime(x, '%S')).astype('int64')
df.head()
# Out:
#       pickup_datetime  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0 2011-10-21 23:54:10        -73.990580        40.761071         -73.981128
# 1 2015-02-03 10:42:03        -73.988403        40.723431         -73.989647
# 2 2014-03-16 18:58:58        -74.015785        40.715110         -74.012029
# 3 2009-06-13 16:10:54        -73.977322        40.787275         -73.958030
# 4 2014-06-12 03:25:56        -73.989683        40.729717         -73.982490
#
#    dropoff_latitude  passenger_count  pickup_year  pickup_month  pickup_day  \
# 0         40.758634                2         2011            10          21
# 1         40.741695                1         2015             2           3
# 2         40.707888                2         2014             3          16
# 3         40.778838                3         2009             6          13
# 4         40.761887                3         2014             6          12
#
#    pickup_hour  pickup_minute  pickup_second
# 0           23             54             10
# 1           10             42              3
# 2           18             58             58
# 3           16             10             54
# 4            3             25             56

# %%
# 將結果使用線性迴歸 / 梯度提升樹分別看結果
df = df.drop(['pickup_datetime'] , axis=1)
scaler = MinMaxScaler()
train_X = scaler.fit_transform(df)
Linear = LinearRegression()
print(f'Linear Reg Score : {cross_val_score(Linear, train_X, train_Y, cv=5).mean()}')
GDBT = GradientBoostingRegressor()
print(f'Gradient Boosting Reg Score : {cross_val_score(GDBT, train_X, train_Y, cv=5).mean()}')
# Out:
# Linear Reg Score : 0.02687687147563771
# Gradient Boosting Reg Score : 0.7115711051879203

# %%
# 增加緯度差, 經度差, 座標距離等三個特徵

df['longitude_diff'] = df['dropoff_longitude'] - df['pickup_longitude']
df['latitude_diff'] = df['dropoff_latitude'] - df['pickup_latitude']
df['distance_2D'] = (df['longitude_diff']**2 + df['latitude_diff']**2)**0.5

df[['distance_2D', 'longitude_diff', 'latitude_diff', 'pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude']].head()
# Out:
#    distance_2D  longitude_diff  latitude_diff  pickup_longitude  \
# 0     0.009761        0.009452      -0.002437        -73.990580
# 1     0.018307       -0.001244       0.018265        -73.988403
# 2     0.008140        0.003756      -0.007222        -74.015785
# 3     0.021056        0.019292      -0.008437        -73.977322
# 4     0.032964        0.007193       0.032170        -73.989683
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude
# 0        40.761071         -73.981128         40.758634
# 1        40.723431         -73.989647         40.741695
# 2        40.715110         -74.012029         40.707888
# 3        40.787275         -73.958030         40.778838
# 4        40.729717         -73.982490         40.761887

# %%
# 結果 : 準確度上升
train_X = scaler.fit_transform(df)
print(f'Linear Reg Score : {cross_val_score(Linear, train_X, train_Y, cv=5).mean()}')
print(f'Gradient Boosting Reg Score : {cross_val_score(GDBT, train_X, train_Y, cv=5).mean()}')
# Out:
# Linear Reg Score : 0.027511120182532454
# Gradient Boosting Reg Score : 0.8053863088644967

# %% [markdown]
# # 作業1
# * 參考今日教材，試著使用經緯度一圈的長度比這一概念，組合出一個新特徵，再觀察原特徵加上新特徵是否提升了正確率?
# =>ANS: 有時候變好一點,有時候變差

# %%
import math

df['longitude_diff_real'] = (df['dropoff_longitude'] - df['pickup_longitude'])
df['latitude_diff'] = df['dropoff_latitude'] - df['pickup_latitude']
df['distance_real'] = ((df['longitude_diff_real']**2)*0.75756 + df['latitude_diff']**2)**0.5
print(df[['distance_2D', 'longitude_diff', 'latitude_diff', 'pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude','longitude_diff_real','distance_real']])
# 觀察結果 
train_X = scaler.fit_transform(df)
print(f'Linear Reg Score : {cross_val_score(Linear, train_X, train_Y, cv=5).mean()}')
print(f'Gradient Boosting Reg Score : {cross_val_score(GDBT, train_X, train_Y, cv=5).mean()}')
# Out:
#       distance_2D  longitude_diff  latitude_diff  pickup_longitude  \
# 0        0.009761        0.009452      -0.002437        -73.990580
# 1        0.018307       -0.001244       0.018265        -73.988403
# 2        0.008140        0.003756      -0.007222        -74.015785
# 3        0.021056        0.019292      -0.008437        -73.977322
# 4        0.032964        0.007193       0.032170        -73.989683
# 5        0.016965       -0.012126      -0.011864        -73.997631
# 6        0.018839       -0.010012      -0.015958        -73.954743
# 7        0.011516       -0.008044      -0.008241        -73.982279
# 8        0.013535        0.009674       0.009466        -73.965039
# 9        0.018643       -0.017187       0.007224        -73.986570
# 10       0.019846       -0.016128       0.011565        -73.953742
# 11       0.069548        0.032590       0.061440        -73.982057
# 12       0.067132        0.029713      -0.060198        -73.983368
# 13       0.029699        0.026265       0.013862        -74.005307
# 14       0.021451        0.002613      -0.021291        -73.970473
# 15       0.020276       -0.000484      -0.020270        -73.951788
# 16       0.046692        0.046225       0.006587        -73.999353
# 17       0.041194        0.023484       0.033844        -74.001532
# 18       0.008381       -0.000333       0.008374        -73.966994
# 19       0.049606       -0.006930      -0.049120        -73.967032
# 20       0.019657        0.008993       0.017479        -73.988503
# 21       0.037534       -0.019687      -0.031957        -73.958500
# 22       0.011513        0.009308       0.006776        -73.966323
# 23       0.040362        0.039207       0.009585        -73.989962
# 24       0.029790       -0.027502      -0.011450        -73.958430
# 25       0.010977       -0.005953      -0.009223        -73.979752
# 26       0.102084        0.051780       0.087977        -73.994117
# 27       0.016527        0.007405       0.014775        -73.980308
# 28       0.030289        0.027419       0.012869        -73.980436
# 29       0.021996       -0.015061      -0.016031        -73.951540
# ...           ...             ...            ...               ...
# 4970     0.054887        0.012210       0.053512        -73.982535
# 4971     0.053337        0.042847       0.031765        -73.994720
# 4972     0.028140       -0.001885      -0.028077        -74.007568
# 4973     0.024577        0.004110       0.024231        -73.988347
# 4974     0.017141        0.009870       0.014014        -74.003000
# 4975     0.030422        0.019562       0.023298        -73.982075
# 4976     0.009238       -0.008933       0.002353        -73.853805
# 4977     0.031266       -0.015014      -0.027425        -73.991290
# 4978     0.011660       -0.005418      -0.010325        -74.007162
# 4979     0.010977        0.000360      -0.010971        -73.977730
# 4980     0.038675        0.002362      -0.038603        -73.967935
# 4981     0.084966        0.072042       0.045047        -73.961487
# 4982     0.103343       -0.102654      -0.011921        -73.863480
# 4987        40.756953         -73.984026         40.757036
# 4988        40.752555         -73.991157         40.731852
# 4989        40.755190         -73.965067         40.755190
# 4990        40.765580         -73.989997         40.751650
# 4991        40.739068         -73.995768         40.726276
# 4992        40.782134         -73.973613         40.750718
# 4993        40.754700         -73.981157         40.737545
# 4994        40.774592         -73.976149         40.782166
# 4995        40.761397         -73.986840         40.759202
# 4996        40.729937         -73.977022         40.726482
# 4997        40.732297         -73.995004         40.750059
# 4998        40.773415         -73.953445         40.782598
# 4999        40.759520         -73.991758         40.744213
#
#       longitude_diff_real  distance_real
# 0                0.009452       0.008580
# 1               -0.001244       0.018297
# 2                0.003756       0.007927
# 3                0.019292       0.018792
# 4                0.007193       0.032774
# 5               -0.012126       0.015879
# 6               -0.010012       0.018182
# 7               -0.008044       0.010814
# 8                0.009674       0.012669
# 9               -0.017187       0.016612
# 10              -0.016128       0.018188
# 11               0.032590       0.067672
# 12               0.029713       0.065518
# 13               0.026265       0.026735
# 14               0.002613       0.021412
# 15              -0.000484       0.020274
# 16               0.046225       0.040769
# 17               0.023484       0.039537
# 18              -0.000333       0.008379
# 19              -0.006930       0.049489
# 20               0.008993       0.019152
# 21              -0.019687       0.036261
# 22               0.009308       0.010562
# 23               0.039207       0.035446
# 24              -0.027502       0.026535
# 25              -0.005953       0.010579
# 26               0.051780       0.098849
# 27               0.007405       0.016120
# 28               0.027419       0.027114
# 29              -0.015061       0.020708
# ...                   ...            ...
# 4970             0.012210       0.054557
# 4971             0.042847       0.048987
# 4972            -0.001885       0.028125
# 4973             0.004110       0.024494
# 4974             0.009870       0.016437
# 4975             0.019562       0.028856
# 4976            -0.008933       0.008123
# 4977            -0.015014       0.030379
# 4978            -0.005418       0.011351
# 4979             0.000360       0.010975
# 4980             0.002362       0.038658
# 4981             0.072042       0.077208
# 4982            -0.102654       0.090139
# 4983            -0.021147       0.018410
# 4984             0.003602       0.027389
# 4985             0.003720       0.011026
# 4986             0.013029       0.032654
# 4987            -0.008328       0.007249
# 4988            -0.000834       0.020716
# 4989             0.000000       0.000000
# 4990            -0.014969       0.019073
# 4991            -0.004459       0.013368
# 4992            -0.015993       0.034362
# 4993            -0.007645       0.018400
# 4994             0.005894       0.009148
# 4995             0.007310       0.006730
# 4996             0.009745       0.009159
# 4997            -0.010392       0.019932
# 4998             0.005015       0.010168
# 4999            -0.026565       0.027729
#
# [5000 rows x 9 columns]
# Linear Reg Score : 0.02626723478893713
# Gradient Boosting Reg Score : 0.8042155649803631

# %% [markdown]
# # 作業2
# * 試著只使用新特徵估計目標值(忽略原特徵)，效果跟作業1的結果比較起來效果如何?=>ANS:變差,可能除了距離外,還有其他相關係數

# %%
train_X = scaler.fit_transform(df[['distance_real']])
print(f'Linear Reg Score : {cross_val_score(Linear, train_X, train_Y, cv=5).mean()}')
print(f'Gradient Boosting Reg Score : {cross_val_score(GDBT, train_X, train_Y, cv=5).mean()}')
# Out:
# Linear Reg Score : 0.0014388889796010495
# Gradient Boosting Reg Score : 0.7379947183068359
